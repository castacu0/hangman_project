# %% [markdown]
# # Change theme IPython Notebook

# %% [markdown]
# ## install the module by typing
#
#     pip install jupyterthemes #or conda
#     !pip install jupyterthemes
#
# ## install a theme:
#
#     jt -t chesterish
#     !jt -t chesterish #inside jupyter
#
# # restore a theme:
#
#     jt -r
#
# # It can be done even inside jupyter notebook by:
#
#     !jt -r

# %%
# !jt -t monokai

# %%
# !jt -r

# %%
Dark Mode Theme # https://blog.usejournal.com/jupyter-dark-mode-themes-b242fb459254

# %% [markdown]
# ![image.png](attachment:image.png)
